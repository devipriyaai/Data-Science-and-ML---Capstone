# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("preprocessed_Rainfall_dataset.csv")

# %%
dataset
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
dataset.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %% [markdown]
# ## Covarience

# %%
dataset.cov(numeric_only = True)
# Out:
#                      day    pressure     maxtemp  temparature     mintemp  \
# day            77.855775    2.526557   -0.899118    -0.700803   -0.456127
# pressure        2.526557   41.149356  -31.795298   -30.777582  -30.138260
# maxtemp        -0.899118  -31.795298   35.740581    33.209949   32.157322
# temparature    -0.700803  -30.777582   33.209949    31.728582   31.201601
# mintemp        -0.456127  -30.138260   32.157322    31.201601   31.294545
# dewpoint       -2.726227  -33.092738   32.260890    31.647422   31.686844
# humidity      -10.534778  -17.744851    1.316352     5.216240    7.826727
# cloud         -21.763208    0.786018  -37.761066   -25.280607  -19.034639
# sunshine        3.781442   -5.001487   11.935019     9.320012    8.105887
# winddirection  30.949173 -345.433326  306.327525   297.644988  288.542032
# windspeed      -2.809481   24.099088  -26.578084   -22.296085  -20.196306
#
#                  dewpoint    humidity       cloud   sunshine  winddirection  \
# ...

# %%
# cloud and humidity is a Positive Coverience
# sunshine and Fabric day is a Positive Coverience

# %% [markdown]
# ## Correlation

# %%
dataset.corr(numeric_only=True)
# Out:
#                     day  pressure   maxtemp  temparature   mintemp  dewpoint  \
# day            1.000000  0.044638 -0.017045    -0.014100 -0.009241 -0.051521
# pressure       0.044638  1.000000 -0.829088    -0.851780 -0.839851 -0.860232
# maxtemp       -0.017045 -0.829088  1.000000     0.986193  0.961534  0.899829
# temparature   -0.014100 -0.851780  0.986193     1.000000  0.990187  0.936866
# mintemp       -0.009241 -0.839851  0.961534     0.990187  1.000000  0.944515
# dewpoint      -0.051521 -0.860232  0.899829     0.936866  0.944515  1.000000
# humidity      -0.118652 -0.274907  0.021882     0.092030  0.139040  0.425282
# cloud         -0.113152  0.005621 -0.289765    -0.205895 -0.156097  0.044635
# sunshine       0.108927 -0.198171  0.507416     0.420545  0.368288  0.185234
# winddirection  0.042970 -0.659693  0.627718     0.647340  0.631879  0.626273
# windspeed     -0.031663  0.373587 -0.442095    -0.393619 -0.359013 -0.378227
#
# ...

# %%
# Temperature and sunshine is a Positive Correlation

# %% [markdown]
# ## VIF

# %%
dataset
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    # calculating vif
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i)for i in range(X.shape[1])]
    return (vif)

# %%
calc_vif(dataset[["day","sunshine"]])
# Out:
#   variables       VIF
# 0       day  1.896849
# 1  sunshine  1.896849
