# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv("Rainfall.csv")

# %%
dataset
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# ...

# %%
dataset.isnull().sum()
# Out:
# day                       0
# pressure                  0
# maxtemp                   0
# temparature               0
# mintemp                   0
# dewpoint                  0
# humidity                  0
# cloud                     0
# rainfall                  0
# sunshine                  0
#          winddirection    1
# windspeed                 1
# dtype: int64

# %%
# Replace the missing value with central tendency mean_median_mode
# Entire Row Delete
# Respective to the problem, have to replace the missing values
# Consider this as a semi supervised,creat a model,so that we can predict the missing values

# %%
# Print data types of all columns
print(dataset.dtypes)
# Out:
# day                         int64
# pressure                  float64
# maxtemp                   float64
# temparature               float64
# mintemp                   float64
# dewpoint                  float64
# humidity                    int64
# cloud                       int64
# rainfall                   object
# sunshine                  float64
#          winddirection    float64
# windspeed                 float64
# dtype: object

# %%
# Strip any leading/trailing spaces from column names
dataset.columns = dataset.columns.str.strip()

# Verify the cleaned column names
print(dataset.columns)
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
dataset.isna().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    1
# windspeed        1
# dtype: int64

# %%
dataset['winddirection'].fillna(dataset['winddirection'].median(), inplace=True)
dataset['windspeed'].fillna(dataset['windspeed'].median(), inplace=True)

# %%
dataset.isna().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
dataset
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
print(dataset.dtypes)
# Out:
# day                int64
# pressure         float64
# maxtemp          float64
# temparature      float64
# mintemp          float64
# dewpoint         float64
# humidity           int64
# cloud              int64
# rainfall          object
# sunshine         float64
# winddirection    float64
# windspeed        float64
# dtype: object

# %%
dataset
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
dataset.isnull().sum()
# Out:
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# rainfall         0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
# Number os Rows and Columns:
print("The Number of Row:",dataset.shape[0])
print("The Number of Columns:",dataset.shape[1])
# Out:
# The Number of Row: 366
# The Number of Columns: 12

# %%
dataset.shape
# Out:
# (366, 12)

# %% [markdown]
# ## Univarite Analysis

# %%
import seaborn as sns

# %%
sns.distplot(dataset['temparature'],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# <Axes: xlabel='temparature', ylabel='Density'>

# %% [markdown]
# ## Bivariate Analysis:Distribution Plot

# %%
sns.jointplot(x='temparature',y='humidity',data=dataset)
plt.show()

# %%
sns.jointplot(x='day',y='sunshine',data=dataset,kind='hex')
plt.show()

# %%
sns.jointplot(x='maxtemp',y='mintemp',data=dataset,kind='kde')
plt.show()

# %%
# Pair plot

# %%
sns.pairplot(dataset,hue='day',diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %% [markdown]
# ## For Categorical Plot

# %%
sns.stripplot(x='day',y='cloud',data=dataset)
plt.show()
